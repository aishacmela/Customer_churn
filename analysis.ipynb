# %%
import pandas as pd

# %%
df = pd.read_csv('netflix_large_user_data.csv', sep=';')
df.head(10)
# Out:
#   Customer ID  Subscription Length (Months)  \
# 0      C00001                            12
# 1      C00002                            12
# 2      C00003                             3
# 3      C00004                             3
# 4      C00005                            24
# 5      C00006                             3
# 6      C00007                            12
# 7      C00008                             6
# 8      C00009                             6
# 9      C00010                             3
#
#    Customer Satisfaction Score (1-10) Daily Watch Time (Hours)  \
# 0                                  10                     4,85
# 1                                   8                     1,75
# 2                                   4                     2,75
# 3                                   7                        3
# 4                                   2                     1,37
# 5                                   4                     4,95
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Subscription Length (Months)',
#        'Customer Satisfaction Score (1-10)', 'Daily Watch Time (Hours)',
#        'Engagement Rate (1-10)', 'Device Used Most Often', 'Genre Preference',
#        'Region', 'Payment History (On-Time/Delayed)', 'Subscription Plan',
#        'Churn Status ', 'Support Queries Logged', 'Age', 'Monthly Income ($)',
#        'Promotional Offers Used', 'Number of Profiles Created'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Subscription Length (Months)  Customer Satisfaction Score (1-10)  \
# count                    1000.00000                         1000.000000
# mean                        9.17700                            5.379000
# std                         8.21859                            2.856487
# min                         1.00000                            1.000000
# 25%                         3.00000                            3.000000
# 50%                         6.00000                            5.000000
# 75%                        12.00000                            8.000000
# max                        24.00000                           10.000000
#
#        Engagement Rate (1-10)  Support Queries Logged          Age  \
# count             1000.000000             1000.000000  1000.000000
# mean                 5.511000                4.951000    43.840000
# std                  2.871607                3.111636    15.356439
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.dtypes
# Out:
# Customer ID                            object
# Subscription Length (Months)            int64
# Customer Satisfaction Score (1-10)      int64
# Daily Watch Time (Hours)              float64
# Engagement Rate (1-10)                  int64
# Device Used Most Often                 object
# Genre Preference                       object
# Region                                 object
# Payment History (On-Time/Delayed)      object
# Subscription Plan                      object
# Churn Status                           object
# Support Queries Logged                  int64
# Age                                     int64
# Monthly Income ($)                      int64
# Promotional Offers Used                 int64
# Number of Profiles Created              int64
# dtype: object

# %%
df['Payment History (On-Time/Delayed)'].value_counts()
# Out:
# Payment History (On-Time/Delayed)
# Delayed    512
# On-Time    488
# Name: count, dtype: int64

# %%
df['Subscription Plan'].value_counts()
# Out:
# Subscription Plan
# Standard    352
# Premium     329
# Basic       319
# Name: count, dtype: int64

# %%
df['Device Used Most Often'].value_counts()
# Out:
# Device Used Most Often
# Laptop      225
# Mobile      201
# Tablet      200
# Smart TV    189
# Desktop     185
# Name: count, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Region
# Asia             205
# Africa           203
# Europe           201
# South America    201
# North America    190
# Name: count, dtype: int64

# %%
df['Customer Satisfaction Score (1-10)'].describe()
# Out:
# count    1000.000000
# mean        5.379000
# std         2.856487
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000
# Name: Customer Satisfaction Score (1-10), dtype: float64

# %%
df['Daily Watch Time (Hours)'].describe()
# Out:
# count    1000.000000
# mean        2.829420
# std         1.302673
# min         0.500000
# 25%         1.650000
# 50%         2.890000
# 75%         3.932500
# max         5.000000
# Name: Daily Watch Time (Hours), dtype: float64

# %%
df['Age'].describe()
# Out:
# count    1000.000000
# mean       43.840000
# std        15.356439
# min        18.000000
# 25%        30.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000
# Name: Age, dtype: float64

# %%
df['Age'].describe().unique()
# Out:
# array([1000.        ,   43.84      ,   15.35643905,   18.        ,
#          30.        ,   44.        ,   57.        ,   70.        ])

# %%
# Numeric columns
print(df.describe())

# Categorical columns
categorical_cols = df.select_dtypes(include='object').columns
for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(df[col].value_counts())
# Out:
#        Subscription Length (Months)  Customer Satisfaction Score (1-10)  \
# count                    1000.00000                         1000.000000
# mean                        9.17700                            5.379000
# std                         8.21859                            2.856487
# min                         1.00000                            1.000000
# 25%                         3.00000                            3.000000
# 50%                         6.00000                            5.000000
# 75%                        12.00000                            8.000000
# max                        24.00000                           10.000000
#
#        Daily Watch Time (Hours)  Engagement Rate (1-10)  \
# count               1000.000000             1000.000000
# mean                   2.829420                5.511000
# std                    1.302673                2.871607
# min                    0.500000                1.000000
# ...

# %%
df['Daily Watch Time (Hours)'].unique()
# Out:
# array(['4,85', '1,75', '2,75', '3', '1,37', '4,95', '0,71', '3,54',
#        '3,79', '3,61', '2,88', '0,78', '1,17', '2,7', '2,01', '0,77',
#        '4,82', '1,08', '4,27', '4,91', '3,56', '0,81', '3,36', '3,11',
#        '4,4', '2,11', '0,92', '2,07', '1,41', '3,77', '3,48', '4,97',
#        '1,68', '3,03', '1,93', '1,61', '4,93', '5', '1,04', '4,7', '2,68',
#        '2,6', '3,01', '3,5', '0,58', '1,48', '4,83', '3,85', '2,95',
#        '1,23', '3,14', '1,36', '2,33', '3,17', '2,46', '3,95', '2,83',
#        '2,26', '2,28', '3,18', '4,32', '1,72', '2,74', '3,12', '4,59',
#        '1,97', '4,03', '4,84', '0,87', '4,42', '1,06', '2,82', '0,83',
#        '4,98', '1,87', '1,21', '1', '0,96', '2,9', '1,84', '4,57', '1,52',
#        '3,25', '3,75', '1,15', '3,67', '3,04', '3,72', '2,02', '1,66',
#        '2,16', '4,3', '3,13', '4,37', '1,29', '2,71', '0,73', '3,27',
#        '4,06', '3,92', '2,66', '2,58', '3,86', '3,33', '1,55', '3,8',
# ...

# %%
df['Daily Watch Time (Hours)'].apply(type).value_counts()
# Out:
# Daily Watch Time (Hours)
# <class 'str'>    1000
# Name: count, dtype: int64

# %%
df['Daily Watch Time (Hours)'].head(10)
# Out:
# 0    4,85
# 1    1,75
# 2    2,75
# 3       3
# 4    1,37
# 5    4,95
# 6    0,71
# 7    3,54
# 8    3,79
# 9    3,61
# Name: Daily Watch Time (Hours), dtype: object

# %%
df['Daily Watch Time (Hours)'] = (
    df['Daily Watch Time (Hours)']
    .str.replace(',', '.', regex=False)
    .astype(float)
)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Customer ID                           0
# Subscription Length (Months)          0
# Customer Satisfaction Score (1-10)    0
# Daily Watch Time (Hours)              0
# Engagement Rate (1-10)                0
# Device Used Most Often                0
# Genre Preference                      0
# Region                                0
# Payment History (On-Time/Delayed)     0
# Subscription Plan                     0
# Churn Status                          0
# Support Queries Logged                0
# Age                                   0
# Monthly Income ($)                    0
# Promotional Offers Used               0
# Number of Profiles Created            0
# dtype: int64
